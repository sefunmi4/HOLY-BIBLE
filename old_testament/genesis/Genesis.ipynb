# %% [markdown]
# #### The Beginning

# %%
"""
A full-stack book experience of Genesis

Database 

Server 

Web 
"""

# %%
from bible.actions import TheActionsOfGod as ACTIONS, TheSpiritOfGod as SPIRIT
# Database 
#1.1 - In the beginning, God created the heavens and the earth. 
#1.2 - Now the earth was formless and empty, darkness was over the surface of the deep, and the Spirit of God was hovering over the waters.  

# Server
#1.1 - “In the beginning, God created the heavens and the earth.”
Heavens = ACTIONS.heavens()
Earth = ACTIONS.planet()
#1.2 - “Now the earth was formless and empty, darkness was over the surface of the deep, and the Spirit of God was hovering over the waters.“ 
Earth.set_adjectives(form = null, matter =null).
surface_of_the_deep = Earth.set_surface(type = deep)
darkness = ACTIONS.darkness()
darkness.over(Surface_of_the_deep)
waters = Earth.get_waters()
SPIRIT.hover(waters)

# Web 
#1.1 - “In the beginning, God created the heavens and the earth.”
# Visual of the observable universe and then focus on the earth.
#1.2 - “Now the earth was formless and empty, darkness was over the surface of the deep, and the Spirit of God was hovering over the waters.“ 
# Show the earth with a formless and empty shape
# Then show darkness over the surface of the deep
# Then show the Spirit of God hovering over the water

# %%
# Database 
#1.3 - And God said, "Let there be light," and there was light. 
#1.4 - God saw that the light was good, and he separated the light from the darkness. 
#1.5 - God called the light "day," and the darkness he called "night." And there was evening, and there was morning - the first day.
 
# Server
#1.3 - And God said, "Let there be light," and there was light. 
light = ACTIONS.said("Let there be light,")
#1.4 - God saw that the light was good, and he separated the light from the darkness
good = ACTIONS.saw(light)  
light, darkness = ACTIONS.separate(light, darkness) 
#1.5 - God called the light "day," and the darkness he called "night." And there was evening, and there was morning - the first day.
GODS_DICTIONARY = {"day,":light, "night.":darkness}
evening = time[GODS_DICTIONARY["day,"] : GODS_DICTIONARY["night."]]
morning = time[GODS_DICTIONARY["night."] : GODS_DICTIONARY["day,"]]
the_first_day = time[evening : morning]

# Web 
#1.3 - And God said, "Let there be light," and there was light. 
#1.4 - God saw that the light was good, and he separated the light from the darkness. 
#1.5 - God called the light "day," and the darkness he called "night." And there was evening, and there was morning - the first day.

# %%
# Database#1.6 - And God said, "Let there be a vault between the waters to separate water from water."#1.7 - So God made the vault and separated the water under the vault from the water above it. And it was so.#1.8 - God called the vault "sky." And there was evening, and there was morning—the second day.# Servervault = ACTIONS.said("Let there be a vault")lower, upper = ACTIONS.separate("water", "water")sky = ACTIONS.call("sky", vault)

# %% [markdown]
# ### TODO- Implement visuals for each verse- Continue the narrative past Genesis 1:8- Clean up placeholder code and separate logic into modules
